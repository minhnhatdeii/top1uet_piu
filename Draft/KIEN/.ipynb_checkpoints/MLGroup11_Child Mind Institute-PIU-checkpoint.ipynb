# %% [markdown]
# # Project : Child Mind Institute - Problematic Internet Use

# %%
#import lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

# %%
train_df.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
# ...

# %%
test_df.head()
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
# 2  00105258                    Summer               10                1
# 3  00115b9f                    Winter                9                0
# 4  0016bb22                    Spring               18                1
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
# 2        Fall             71.0            Fall     16.648696             56.5
# 3        Fall             71.0          Summer     18.292347             56.0
# 4      Summer              NaN             NaN           NaN              NaN
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 82 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   object
#  1   Basic_Demos-Enroll_Season               3960 non-null   object
#  2   Basic_Demos-Age                         3960 non-null   int64
#  3   Basic_Demos-Sex                         3960 non-null   int64
#  4   CGAS-Season                             2555 non-null   object
#  5   CGAS-CGAS_Score                         2421 non-null   float64
#  6   Physical-Season                         3310 non-null   object
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 59 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      20 non-null     object
#  1   Basic_Demos-Enroll_Season               20 non-null     object
#  2   Basic_Demos-Age                         20 non-null     int64
#  3   Basic_Demos-Sex                         20 non-null     int64
#  4   CGAS-Season                             10 non-null     object
#  5   CGAS-CGAS_Score                         8 non-null      float64
#  6   Physical-Season                         14 non-null     object
#  7   Physical-BMI                            13 non-null     float64
#  8   Physical-Height                         13 non-null     float64
#  9   Physical-Weight                         13 non-null     float64
# ...

# %%
# feature category
features = ["Basic_Demos-Sex","FGC-FGC_CU_Zone","FGC-FGC_GSND_Zone","FGC-FGC_GSD_Zone","FGC-FGC_PU_Zone","FGC-FGC_SRL_Zone","FGC-FGC_SRR_Zone","FGC-FGC_TL_Zone",
            "BIA-BIA_Activity_Level_num","BIA-BIA_Frame_num","PCIAT-PCIAT_01","PCIAT-PCIAT_02","PCIAT-PCIAT_03","PCIAT-PCIAT_04","PCIAT-PCIAT_05","PCIAT-PCIAT_06",
            "PCIAT-PCIAT_07","PCIAT-PCIAT_08","PCIAT-PCIAT_09","PCIAT-PCIAT_10","PCIAT-PCIAT_11","PCIAT-PCIAT_12","PCIAT-PCIAT_13","PCIAT-PCIAT_14","PCIAT-PCIAT_15",
            "PCIAT-PCIAT_16","PCIAT-PCIAT_17","PCIAT-PCIAT_18","PCIAT-PCIAT_19","PCIAT-PCIAT_20","PreInt_EduHx-computerinternet_hoursday"]
def convert_cate(df, features):
    for i in features:
        if i in df.columns:
            df[i] = df[i].astype("category")
convert_cate(test_df, features)
convert_cate(train_df, features)

# %%
# feature float64
features = ["Basic_Demos-Age","Physical-BMI","Physical-Height","Physical-Weight","FGC-FGC_GSND","FGC-FGC_GSD","FGC-FGC_SRL","FGC-FGC_SRR","BIA-BIA_BMC",
           "BIA-BIA_BMI","BIA-BIA_BMR","BIA-BIA_DEE","BIA-BIA_ECW","BIA-BIA_FFM","BIA-BIA_FFMI","BIA-BIA_FMI","BIA-BIA_Fat","BIA-BIA_ICW","BIA-BIA_LDM",
           "BIA-BIA_LST","BIA-BIA_SMM","BIA-BIA_TBW","PAQ_A-PAQ_A_Total","PAQ_C-PAQ_C_Total"]
def convert_float(df, features):
    for i in features:
        if i in df.columns:
            df[i] = df[i].astype("float64")
convert_float(test_df, features)
convert_float(train_df, features)

# %%
# feature string
features = ["id","Basic_Demos-Enroll_Season","CGAS-Season","Physical-Season","FGC-Season","BIA-Season","PAQ_A-Season","PAQ_C-Season","PCIAT-Season","SDS-Season","PreInt_EduHx-Season"]
def convert_string(df, features):
    for i in features:
        if i in df.columns:
            df[i] = df[i].astype("string")
convert_string(test_df, features)
convert_string(train_df, features)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 59 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      20 non-null     string
#  1   Basic_Demos-Enroll_Season               20 non-null     string
#  2   Basic_Demos-Age                         20 non-null     float64
#  3   Basic_Demos-Sex                         20 non-null     category
#  4   CGAS-Season                             10 non-null     string
#  5   CGAS-CGAS_Score                         8 non-null      float64
#  6   Physical-Season                         14 non-null     string
#  7   Physical-BMI                            13 non-null     float64
#  8   Physical-Height                         13 non-null     float64
#  9   Physical-Weight                         13 non-null     float64
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 82 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      3960 non-null   string
#  1   Basic_Demos-Enroll_Season               3960 non-null   string
#  2   Basic_Demos-Age                         3960 non-null   float64
#  3   Basic_Demos-Sex                         3960 non-null   category
#  4   CGAS-Season                             2555 non-null   string
#  5   CGAS-CGAS_Score                         2421 non-null   float64
#  6   Physical-Season                         3310 non-null   string
#  7   Physical-BMI                            3022 non-null   float64
#  8   Physical-Height                         3027 non-null   float64
#  9   Physical-Weight                         3076 non-null   float64
# ...

# %%
train_df["sii"].value_counts().to_frame()
# Out:
#      count
# sii
# 0.0   1594
# 1.0    730
# 2.0    378
# 3.0     34

# %%
train_df["sii"].value_counts(normalize=True).to_frame()
# Out:
#      proportion
# sii
# 0.0    0.582602
# 1.0    0.266813
# 2.0    0.138158
# 3.0    0.012427

# %% [markdown]
# Physical Season

# %%
train_df["Physical-Season"].value_counts(normalize=True).to_frame()
# Out:
#                  proportion
# Physical-Season
# Spring             0.280665
# Winter               0.2429
# Summer             0.238973
# Fall               0.237462

# %%
sns.countplot(data=train_df, x = 'Physical-Season', hue="sii", palette = "Oranges")
# Out:
# <Axes: xlabel='Physical-Season', ylabel='count'>

# %% [markdown]
# Physical BMI

# %%
sns.countplot(data=train_df, x = 'Physical-BMI', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='Physical-BMI', ylabel='count'>

# %% [markdown]
# #Physical Height

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Physical-Height', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Physical-Waist_Circumference

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Physical-Waist_Circumference', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Physical-Diastolic_BP

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Physical-Diastolic_BP', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Physical-HeartRate

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Physical-HeartRate', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Physical-Systolic_BP

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Physical-Systolic_BP', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Fitness_Endurance-Season

# %%
sns.countplot(data=train_df, x = 'Fitness_Endurance-Season', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='Fitness_Endurance-Season', ylabel='count'>

# %% [markdown]
# Fitness_Endurance-Max_Stage

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Fitness_Endurance-Max_Stage', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Fitness_Endurance-Time_Mins

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Fitness_Endurance-Time_Mins', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# Fitness_Endurance-Time_Sec

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='Fitness_Endurance-Time_Sec', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FitnessGram Child

# %% [markdown]
# FGC-Season

# %%
sns.countplot(data=train_df, x = 'FGC-Season', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-Season', ylabel='count'>

# %% [markdown]
# FGC-FGC_CU

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_CU', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_CU_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_CU_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_CU_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_GSND

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_GSND', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_GSND_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_GSND_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_GSND_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_GSD

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_GSD', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_GSD_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_GSD_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_GSD_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_PU

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_PU', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_PU_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_PU_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_SRL

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_SRL', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_SRL_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_SRL_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_SRL_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_SRR

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_SRR', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_SRR_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_SRR_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_SRR_Zone', ylabel='count'>

# %% [markdown]
# FGC-FGC_TL

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=train_df, x='FGC-FGC_TL', hue='sii', palette='dark')
plt.xticks(rotation=90)  # Xoay nhãn để dễ đọc hơn
plt.show()

# %% [markdown]
# FGC-FGC_TL_Zone

# %%
sns.countplot(data=train_df, x = 'FGC-FGC_TL_Zone', hue="sii", palette = "dark")
# Out:
# <Axes: xlabel='FGC-FGC_TL_Zone', ylabel='count'>
